# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# The preprocessing of the raw data taken to achieve the data that will be employed is executed here.
#
# Steps followed
# 1. [Load data](#1.-Load-data)
# 2. [Preprocess climate data](#2.-Preprocess-climate-data)
# 3. [Preprocess main](#3.-Preprocess-main-data)
# 4. [Merge features](#4.-Merge-features)
# 5. [Save data](#5-Save-data)

# %% [markdown]
# ## Load packages

# %%
# Set Git path
import os 
CURRENT_PATH = os.getcwd()

# data manipulation
from pathlib import Path
import pandas as pd

# %%
data_path = Path('../../data/01-Preprocessing/')

# %% [markdown]
# ## 1. Load data

# %%
# Loading required data to blend
main = pd.read_pickle(data_path/'main.pkl')
climate = pd.read_pickle(data_path/'climate.pkl')
cropland_state = pd.read_pickle(data_path/'cropland_state.pkl')

# %% [markdown]
# ## 2. Preprocess climate data

# %% [markdown]
# Necessary to be merged with main:
# - Unify colname of year as in main data
# - As data come in months, unify data per year/state obtaining two new columns:
#     - mean of each year
#     - std of each year

# %%
climate['DATE'] = pd.to_datetime(climate['DATE'])
climate = climate.rename(columns={'DATE': 'YEAR'})
climate['YEAR'] = climate['YEAR'].dt.year

agg_df = climate.groupby(['YEAR','State']).agg(['mean', 'std'])
new_columns = [f'{col}_{stat}' for col, stat in agg_df.columns]
agg_df.columns = new_columns

climate = agg_df.copy()
climate.reset_index(inplace=True)
climate = climate.rename_axis(None, axis=1)
climate.rename(columns={'State': 'LOCATION_DESC'}, inplace=True)
climate = climate.apply(lambda x: x.str.upper() if x.dtype == 'object' else x)

climate
# Out:
#       YEAR  LOCATION_DESC   Average Temperature_mean  \
# 0     1895        ALABAMA                  61.641667
# 1     1895        ARIZONA                  58.491667
# 2     1895       ARKANSAS                  58.858333
# 3     1895     CALIFORNIA                  56.458333
# 4     1895       COLORADO                  42.433333
# ...    ...            ...                        ...
# 6237  2022       VIRGINIA                  32.900000
# 6238  2022     WASHINGTON                  31.200000
# 6239  2022  WEST VIRGINIA                  27.400000
# 6240  2022      WISCONSIN                   9.200000
# 6241  2022        WYOMING                  23.000000
#
#        Average Temperature_std   Cooling Degree Days_mean  \
# 0                    15.202898                 153.750000
# 1                    14.733602                 206.250000
# 2                    17.049471                 142.083333
# 3                    11.784771                  42.833333
# 4                    17.281747                  10.750000
# ...                        ...                        ...
# 6237                       NaN                   0.000000
# 6238                       NaN                   0.000000
# 6239                       NaN                   0.000000
# 6240                       NaN                   0.000000
# 6241                       NaN                   0.000000
#
#        Cooling Degree Days_std   Heating Degree Days_mean  \
# 0                   184.686528                 274.000000
# 1                   223.985034                 192.333333
# 2                   179.073097                 337.500000
# 3                    57.142300                 290.583333
# 4                    18.091309                 693.750000
# ...                        ...                        ...
# 6237                       NaN                 994.000000
# 6238                       NaN                 869.000000
# 6239                       NaN                1155.000000
# 6240                       NaN                1622.000000
# 6241                       NaN                1270.000000
#
#        Heating Degree Days_std   Maximum Temperature_mean  \
# 0                   303.660097                  73.066667
# 1                   215.727662                  71.408333
# 2                   363.964908                  69.933333
# 3                   236.191547                  68.416667
# 4                   500.796298                  57.016667
# ...                        ...                        ...
# 6237                       NaN                  42.800000
# 6238                       NaN                  37.000000
# 6239                       NaN                  37.000000
# 6240                       NaN                  19.600000
# 6241                       NaN                  34.700000
#
#        Maximum Temperature_std   Minimum Temperature_mean  \
# 0                    15.096136                  50.208333
# 1                    15.850406                  45.550000
# 2                    17.121827                  47.766667
# 3                    14.054105                  44.475000
# 4                    18.314219                  27.891667
# ...                        ...                        ...
# 6237                       NaN                  23.100000
# 6238                       NaN                  25.400000
# 6239                       NaN                  17.800000
# 6240                       NaN                  -1.300000
# 6241                       NaN                  11.200000
#
#        Minimum Temperature_std   Palmer Drought Severity Index (PDSI)_mean  \
# 0                    15.393237                                   -0.325833
# 1                    13.858670                                    1.408333
# 2                    17.078926                                   -0.200833
# 3                     9.570801                                    0.868333
# 4                    16.279740                                    2.825833
# ...                        ...                                         ...
# 6237                       NaN                                   -1.340000
# 6238                       NaN                                    1.440000
# 6239                       NaN                                    0.720000
# 6240                       NaN                                   -1.460000
# 6241                       NaN                                   -4.310000
#
#        Palmer Drought Severity Index (PDSI)_std   Precipitation_mean  \
# 0                                      0.813080             4.200000
# 1                                      0.679971             0.950833
# 2                                      1.196688             3.781667
# 3                                      1.096348             1.906667
# 4                                      0.685121             1.635000
# ...                                         ...                  ...
# 6237                                        NaN             4.510000
# 6238                                        NaN             6.580000
# 6239                                        NaN             4.860000
# 6240                                        NaN             0.500000
# 6241                                        NaN             0.790000
#
#        Precipitation_std
# 0               2.039947
# 1               0.915478
# 2               1.972999
# 3               2.495794
# 4               0.731207
# ...                  ...
# 6237                 NaN
# 6238                 NaN
# 6239                 NaN
# 6240                 NaN
# 6241                 NaN
#
# [6242 rows x 16 columns]

# %% [markdown]
# ## 3. Preprocess main data

# %% [markdown]
# Clean data before merging:
# - Filter NaNs < 20% ¡PER STATE!
# - Inputation by mean of NaNs for the remaining
#
# **Disclaimer** -> As it were filtered the columns by state, there will be NaNs in the whole dataset

# %%
# NaNs filter PER STATE
# Group by 'state' and filter columns with missing values < 20% for each state
filtered_dfs = {}
for state, state_df in main.groupby('LOCATION_DESC'):
    missing_percentages = state_df.isna().mean() * 100
    columns_to_keep = missing_percentages[missing_percentages < 20].index
    filtered_df = state_df.loc[:, columns_to_keep]
    # Fill missing values with column means
    filtered_df = filtered_df.fillna(filtered_df.mean(numeric_only=True))
    filtered_dfs[state] = filtered_df

# Merge all filtered DataFrames into one by 'year' column
main = pd.concat(filtered_dfs.values(), ignore_index=True)
main = main.sort_values('YEAR')
main = main.reset_index(drop=True)

main
# Out:
#       YEAR LOCATION_DESC  CORN - ACRES PLANTED  CORN, GRAIN - ACRES HARVESTED  \
# 0     1919       ARIZONA                  31.0                           22.0
# 1     1920       ARIZONA                  29.0                           21.0
# 2     1921       ARIZONA                  35.0                           21.0
# 3     1922       ARIZONA                  39.0                           23.0
# 4     1923       ARIZONA                  33.0                           23.0
# ...    ...           ...                   ...                            ...
# 4642  2022       ARIZONA                  85.0                           30.0
# 4643  2022      NEBRASKA                9600.0                         9300.0
# 4644  2022        NEVADA                  14.0                            NaN
# 4645  2022         MAINE                  33.0                            NaN
# 4646  2022       WYOMING                  95.0                           69.0
#
#       CORN, GRAIN - PRODUCTION, MEASURED IN BU  \
# 0                                 4.620000e+02
# 1                                 2.730000e+02
# 2                                 3.990000e+02
# 3                                 3.910000e+02
# 4                                 4.370000e+02
# ...                                        ...
# 4642                              2.027508e+03
# 4643                              1.599600e+06
# 4644                                       NaN
# 4645                                       NaN
# 4646                              3.231158e+03
#
#       CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  \
# 0                                      21.000000
# 1                                      13.000000
# 2                                      19.000000
# 3                                      17.000000
# 4                                      19.000000
# ...                                          ...
# 4642                                   85.770874
# 4643                                  172.000000
# 4644                                         NaN
# 4645                                         NaN
# 4646                                   74.451020
#
#       CORN, SILAGE - ACRES HARVESTED  \
# 0                           6.000000
# 1                           5.000000
# 2                           8.000000
# 3                           4.000000
# 4                           4.000000
# ...                              ...
# 4642                       16.360118
# 4643                      276.201622
# 4644                        9.534034
# 4645                       24.263921
# 4646                       28.836364
#
#       CORN, SILAGE - PRODUCTION, MEASURED IN TONS  \
# 0                                       35.000000
# 1                                       32.000000
# 2                                       54.000000
# 3                                       26.000000
# 4                                       28.000000
# ...                                           ...
# 4642                                   296.550026
# 4643                                  2955.949759
# 4644                                    65.214162
# 4645                                   294.388543
# 4646                                   392.989102
#
#       CORN, SILAGE - YIELD, MEASURED IN TONS / ACRE  \
# 0                                          5.900000
# 1                                          6.500000
# 2                                          6.700000
# 3                                          6.600000
# 4                                          7.000000
# ...                                             ...
# 4642                                      17.886408
# 4643                                      11.135417
# 4644                                      15.683562
# 4645                                      13.940625
# 4646                                      13.525510
#
#       CORN, GRAIN - PRODUCTION, MEASURED IN $
# 0                                  929.000000
# 1                                  420.000000
# 2                                  459.000000
# 3                                  461.000000
# 4                                  485.000000
# ...                                       ...
# 4642                              8436.572816
# 4643                                      NaN
# 4644                                      NaN
# 4645                                      NaN
# 4646                                      NaN
#
# [4647 rows x 10 columns]

# %% [markdown]
# ## 4. Merge features

# %% [markdown]
# **Only in existing rows where the output is present**

# %% [markdown]
# ### 4.1 Climate on Main

# %%
# Add climate
data = pd.merge(main, climate, on=['YEAR', 'LOCATION_DESC'], how='left')

for col in climate.columns: # Complete missing from climate with median
   if col != 'YEAR' and col != 'LOCATION_DESC':  
        median = data[col].median()
        data[col].fillna(median, inplace=True)

data
# Out:
#       YEAR LOCATION_DESC  CORN - ACRES PLANTED  CORN, GRAIN - ACRES HARVESTED  \
# 0     1919       ARIZONA                  31.0                           22.0
# 1     1920       ARIZONA                  29.0                           21.0
# 2     1921       ARIZONA                  35.0                           21.0
# 3     1922       ARIZONA                  39.0                           23.0
# 4     1923       ARIZONA                  33.0                           23.0
# ...    ...           ...                   ...                            ...
# 4642  2022       ARIZONA                  85.0                           30.0
# 4643  2022      NEBRASKA                9600.0                         9300.0
# 4644  2022        NEVADA                  14.0                            NaN
# 4645  2022         MAINE                  33.0                            NaN
# 4646  2022       WYOMING                  95.0                           69.0
#
#       CORN, GRAIN - PRODUCTION, MEASURED IN BU  \
# 0                                 4.620000e+02
# 1                                 2.730000e+02
# 2                                 3.990000e+02
# 3                                 3.910000e+02
# 4                                 4.370000e+02
# ...                                        ...
# 4642                              2.027508e+03
# 4643                              1.599600e+06
# 4644                                       NaN
# 4645                                       NaN
# 4646                              3.231158e+03
#
#       CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  \
# 0                                      21.000000
# 1                                      13.000000
# 2                                      19.000000
# 3                                      17.000000
# 4                                      19.000000
# ...                                          ...
# 4642                                   85.770874
# 4643                                  172.000000
# 4644                                         NaN
# 4645                                         NaN
# 4646                                   74.451020
#
#       CORN, SILAGE - ACRES HARVESTED  \
# 0                           6.000000
# 1                           5.000000
# 2                           8.000000
# 3                           4.000000
# 4                           4.000000
# ...                              ...
# 4642                       16.360118
# 4643                      276.201622
# 4644                        9.534034
# 4645                       24.263921
# 4646                       28.836364
#
#       CORN, SILAGE - PRODUCTION, MEASURED IN TONS  \
# 0                                       35.000000
# 1                                       32.000000
# 2                                       54.000000
# 3                                       26.000000
# 4                                       28.000000
# ...                                           ...
# 4642                                   296.550026
# 4643                                  2955.949759
# 4644                                    65.214162
# 4645                                   294.388543
# 4646                                   392.989102
#
#       CORN, SILAGE - YIELD, MEASURED IN TONS / ACRE  \
# 0                                          5.900000
# 1                                          6.500000
# 2                                          6.700000
# 3                                          6.600000
# 4                                          7.000000
# ...                                             ...
# 4642                                      17.886408
# 4643                                      11.135417
# 4644                                      15.683562
# 4645                                      13.940625
# 4646                                      13.525510
#
#       CORN, GRAIN - PRODUCTION, MEASURED IN $  ...   Heating Degree Days_mean  \
# 0                                  929.000000  ...                 214.666667
# 1                                  420.000000  ...                 211.000000
# 2                                  459.000000  ...                 167.750000
# 3                                  461.000000  ...                 218.583333
# 4                                  485.000000  ...                 200.500000
# ...                                       ...  ...                        ...
# 4642                              8436.572816  ...                 444.000000
# 4643                                      NaN  ...                1265.000000
# 4644                                      NaN  ...                 663.000000
# 4645                                      NaN  ...                1536.000000
# 4646                                      NaN  ...                1270.000000
#
#        Heating Degree Days_std   Maximum Temperature_mean  \
# 0                   229.288755                  71.300000
# 1                   213.963038                  71.208333
# 2                   182.168815                  73.958333
# 3                   229.390282                  72.358333
# 4                   204.252740                  71.116667
# ...                        ...                        ...
# 4642                417.486527                  57.200000
# 4643                417.486527                  39.500000
# 4644                417.486527                  45.800000
# 4645                417.486527                  21.900000
# 4646                417.486527                  34.700000
#
#        Maximum Temperature_std   Minimum Temperature_mean  \
# 0                    16.231171                  44.825000
# 1                    15.444002                  44.375000
# 2                    13.132850                  45.858333
# 3                    16.656064                  44.858333
# 4                    14.752000                  44.600000
# ...                        ...                        ...
# 4642                 17.462243                  30.300000
# 4643                 17.462243                  11.700000
# 4644                 17.462243                  22.400000
# 4645                 17.462243                  -0.200000
# 4646                 17.462243                  11.200000
#
#        Minimum Temperature_std   Palmer Drought Severity Index (PDSI)_mean  \
# 0                    15.267203                                    2.422500
# 1                    13.085184                                    2.357500
# 2                    13.304918                                   -0.372500
# 3                    14.897496                                    0.980833
# 4                    13.089760                                    0.172500
# ...                        ...                                         ...
# 4642                 15.427858                                   -3.140000
# 4643                 15.427858                                   -1.880000
# 4644                 15.427858                                   -3.840000
# 4645                 15.427858                                   -0.860000
# 4646                 15.427858                                   -4.310000
#
#        Palmer Drought Severity Index (PDSI)_std   Precipitation_mean  \
# 0                                      1.430627             1.372500
# 1                                      2.827209             1.069167
# 2                                      2.107459             1.136667
# 3                                      1.182374             1.010833
# 4                                      1.478286             1.266667
# ...                                         ...                  ...
# 4642                                   1.184574             0.300000
# 4643                                   1.184574             0.250000
# 4644                                   1.184574             0.140000
# 4645                                   1.184574             2.430000
# 4646                                   1.184574             0.790000
#
#        Precipitation_std
# 0               1.194854
# 1               0.813896
# 2               1.200578
# 3               0.682368
# 4               0.986881
# ...                  ...
# 4642            1.490589
# 4643            1.490589
# 4644            1.490589
# 4645            1.490589
# 4646            1.490589
#
# [4647 rows x 24 columns]

# %% [markdown]
# ### 4.2 Cropland on current 4.1

# %%
cropland_state.rename(columns={'Regions and States': 'LOCATION_DESC'}, inplace=True)
cropland_state['LOCATION_DESC'] = cropland_state['LOCATION_DESC'].str.upper()

# Add cropland
data = data.merge(cropland_state, on=['YEAR', 'LOCATION_DESC'], how='left')

for col in climate.columns: # Complete missing from cropland value with median
   if col != 'YEAR' and col != 'LOCATION_DESC':  
        median = data[col].median()
        data[col].fillna(median, inplace=True)
        
data
# Out:
#       YEAR LOCATION_DESC  CORN - ACRES PLANTED  CORN, GRAIN - ACRES HARVESTED  \
# 0     1919       ARIZONA                  31.0                           22.0
# 1     1920       ARIZONA                  29.0                           21.0
# 2     1921       ARIZONA                  35.0                           21.0
# 3     1922       ARIZONA                  39.0                           23.0
# 4     1923       ARIZONA                  33.0                           23.0
# ...    ...           ...                   ...                            ...
# 4642  2022       ARIZONA                  85.0                           30.0
# 4643  2022      NEBRASKA                9600.0                         9300.0
# 4644  2022        NEVADA                  14.0                            NaN
# 4645  2022         MAINE                  33.0                            NaN
# 4646  2022       WYOMING                  95.0                           69.0
#
#       CORN, GRAIN - PRODUCTION, MEASURED IN BU  \
# 0                                 4.620000e+02
# 1                                 2.730000e+02
# 2                                 3.990000e+02
# 3                                 3.910000e+02
# 4                                 4.370000e+02
# ...                                        ...
# 4642                              2.027508e+03
# 4643                              1.599600e+06
# 4644                                       NaN
# 4645                                       NaN
# 4646                              3.231158e+03
#
#       CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  \
# 0                                      21.000000
# 1                                      13.000000
# 2                                      19.000000
# 3                                      17.000000
# 4                                      19.000000
# ...                                          ...
# 4642                                   85.770874
# 4643                                  172.000000
# 4644                                         NaN
# 4645                                         NaN
# 4646                                   74.451020
#
#       CORN, SILAGE - ACRES HARVESTED  \
# 0                           6.000000
# 1                           5.000000
# 2                           8.000000
# 3                           4.000000
# 4                           4.000000
# ...                              ...
# 4642                       16.360118
# 4643                      276.201622
# 4644                        9.534034
# 4645                       24.263921
# 4646                       28.836364
#
#       CORN, SILAGE - PRODUCTION, MEASURED IN TONS  \
# 0                                       35.000000
# 1                                       32.000000
# 2                                       54.000000
# 3                                       26.000000
# 4                                       28.000000
# ...                                           ...
# 4642                                   296.550026
# 4643                                  2955.949759
# 4644                                    65.214162
# 4645                                   294.388543
# 4646                                   392.989102
#
#       CORN, SILAGE - YIELD, MEASURED IN TONS / ACRE  \
# 0                                          5.900000
# 1                                          6.500000
# 2                                          6.700000
# 3                                          6.600000
# 4                                          7.000000
# ...                                             ...
# 4642                                      17.886408
# 4643                                      11.135417
# 4644                                      15.683562
# 4645                                      13.940625
# 4646                                      13.525510
#
#       CORN, GRAIN - PRODUCTION, MEASURED IN $  ...   Heating Degree Days_std  \
# 0                                  929.000000  ...                229.288755
# 1                                  420.000000  ...                213.963038
# 2                                  459.000000  ...                182.168815
# 3                                  461.000000  ...                229.390282
# 4                                  485.000000  ...                204.252740
# ...                                       ...  ...                       ...
# 4642                              8436.572816  ...                417.486527
# 4643                                      NaN  ...                417.486527
# 4644                                      NaN  ...                417.486527
# 4645                                      NaN  ...                417.486527
# 4646                                      NaN  ...                417.486527
#
#        Maximum Temperature_mean   Maximum Temperature_std  \
# 0                     71.300000                 16.231171
# 1                     71.208333                 15.444002
# 2                     73.958333                 13.132850
# 3                     72.358333                 16.656064
# 4                     71.116667                 14.752000
# ...                         ...                       ...
# 4642                  57.200000                 17.462243
# 4643                  39.500000                 17.462243
# 4644                  45.800000                 17.462243
# 4645                  21.900000                 17.462243
# 4646                  34.700000                 17.462243
#
#        Minimum Temperature_mean   Minimum Temperature_std  \
# 0                     44.825000                 15.267203
# 1                     44.375000                 13.085184
# 2                     45.858333                 13.304918
# 3                     44.858333                 14.897496
# 4                     44.600000                 13.089760
# ...                         ...                       ...
# 4642                  30.300000                 15.427858
# 4643                  11.700000                 15.427858
# 4644                  22.400000                 15.427858
# 4645                  -0.200000                 15.427858
# 4646                  11.200000                 15.427858
#
#        Palmer Drought Severity Index (PDSI)_mean  \
# 0                                       2.422500
# 1                                       2.357500
# 2                                      -0.372500
# 3                                       0.980833
# 4                                       0.172500
# ...                                          ...
# 4642                                   -3.140000
# 4643                                   -1.880000
# 4644                                   -3.840000
# 4645                                   -0.860000
# 4646                                   -4.310000
#
#        Palmer Drought Severity Index (PDSI)_std   Precipitation_mean  \
# 0                                      1.430627             1.372500
# 1                                      2.827209             1.069167
# 2                                      2.107459             1.136667
# 3                                      1.182374             1.010833
# 4                                      1.478286             1.266667
# ...                                         ...                  ...
# 4642                                   1.184574             0.300000
# 4643                                   1.184574             0.250000
# 4644                                   1.184574             0.140000
# 4645                                   1.184574             2.430000
# 4646                                   1.184574             0.790000
#
#        Precipitation_std  VALUE
# 0               1.194854    NaN
# 1               0.813896    NaN
# 2               1.200578    NaN
# 3               0.682368    NaN
# 4               0.986881    NaN
# ...                  ...    ...
# 4642            1.490589    NaN
# 4643            1.490589    NaN
# 4644            1.490589    NaN
# 4645            1.490589    NaN
# 4646            1.490589    NaN
#
# [4647 rows x 25 columns]

# %% [markdown]
# ## 5. Save data

# %%
data.to_pickle(data_path/'data.pkl')
